# %% [markdown]
# <a href="https://colab.research.google.com/github/GreisonMontenari/Ebac-AnaliseDados/blob/main/Profissao_Analista_de_dados_M37_Exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Amazon Web Services;</li>
#   <li>AWS IAM;</li>
#   <li>AWS S3;</li>
#   <li>AWS Athena.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Amazon Web Services

# %% [markdown]
#  1. Crie uma conta na [AWS](https://portal.aws.amazon.com/);
#  1. Acesse a sua conta e selecione a região mais próxima da sua residência.

# %% [markdown]
# ## 2\. AWS S3

# %%
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.to_csv('iris.csv', index=False, header=False)

# %% [markdown]
# ![Sem título01.png](data:image/png;base64,...)

# %% [markdown]
# Replique as atividades do item 3.3 em sua conta.

# %% [markdown]
# ## 3\. AWS Athena

# %% [markdown]
# Replique as atividades do item 4.3 em sua conta.

# %% [markdown]
# ![Sem título03.png](data:image/png;base64,...)

# %% [markdown]
# ![Sem título03.png](data:image/png;base64,...)

# %% [markdown]
# ![Sem título03.png](data:image/png;base64,...)
