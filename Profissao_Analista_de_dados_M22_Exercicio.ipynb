# %% [markdown]
# <a href="https://colab.research.google.com/github/GreisonMontenari/Cartorioebac/blob/main/Profissao_Analista_de_dados_M22_Exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Fundamentos de Aprendizado de Máquina
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Teoria;</li>
#   <li>Atributos categóricos;</li>
#   <li>Atributos numéricos;</li>
#   <li>Dados faltantes.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Pinguins

# %% [markdown]
# Neste exercício, vamos utilizar uma base de dados com informações sobre penguins. A idéia é preparar a base de dados para prever a espécie do penguin (variável resposta) baseado em suas características físicas e geográficas (variáveis preditivas).

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = sns.load_dataset('penguins')

# %%
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### **1.1. Valores nulos**

# %% [markdown]
# A base de dados possui valores faltantes, utilize os conceitos da aula para trata-los.

# %%
import seaborn as sns

# Carregar o dataset "penguins"
penguins_df = sns.load_dataset("penguins")

# Remover valores ausentes na coluna 'sex'
penguins_clean_df = penguins_df.dropna(subset=['sex'])

# Exibir as primeiras linhas do DataFrame limpo
penguins_clean_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
# resposta da questão 1.1

penguins_clean_df = penguins_df.dropna(subset=['sex'])
penguins_clean_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
print(penguins_clean_df.isna().sum())
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# ### **1.2. Variáveis numéricas**

# %% [markdown]
# Identifique as variáveis numéricas e crie uma nova coluna **padronizando** seus valores. A nova coluna deve ter o mesmo nome da coluna original acrescidade de "*_std*".

# %% [markdown]
# > **Nota**: Você não deve tratar a variável resposta.

# %%
# resposta da questão 1.2

penguins_clean_df[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']].head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 4            36.7           19.3              193.0       3450.0
# 5            39.3           20.6              190.0       3650.0

# %%
# bill_length_mm

media_bill_lenght = penguins_clean_df['bill_length_mm'].mean()
print(media_bill_lenght)

desvio_padrao_bill_lenght = penguins_clean_df['bill_length_mm'].std()
print(desvio_padrao_bill_lenght)

penguins_clean_df['bill_length_mm_std'] = penguins_clean_df['bill_length_mm'].apply(lambda b_l_mm: (b_l_mm - media_bill_lenght) / desvio_padrao_bill_lenght)
# Out:
# 43.99279279279279
# 5.468668342647562
# <ipython-input-10-b981ad15f701>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['bill_length_mm_std'] = penguins_clean_df['bill_length_mm'].apply(lambda b_l_mm: (b_l_mm - media_bill_lenght) / desvio_padrao_bill_lenght)

# %%
# bill_depth_mm

media_bill_depth = penguins_clean_df['bill_depth_mm'].mean()
print(media_bill_depth)

desvio_padrao_bill_depth = penguins_clean_df['bill_depth_mm'].std()
print(desvio_padrao_bill_depth)

penguins_clean_df['bill_depth_mm_std'] = penguins_clean_df['bill_depth_mm'].apply(lambda b_d_mm: (b_d_mm - media_bill_depth) / desvio_padrao_bill_depth)
# Out:
# 17.164864864864864
# 1.9692354633199
# <ipython-input-11-bf88cf3ea396>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['bill_depth_mm_std'] = penguins_clean_df['bill_depth_mm'].apply(lambda b_d_mm: (b_d_mm - media_bill_depth) / desvio_padrao_bill_depth)

# %%
# flipper_length_mm

media_flipper_lenght = penguins_clean_df['flipper_length_mm'].mean()
print(media_flipper_lenght)

desvio_padrao_flipper_lenght = penguins_clean_df['flipper_length_mm'].std()
print(desvio_padrao_flipper_lenght)

penguins_clean_df['flipper_length_mm_std'] = penguins_clean_df['flipper_length_mm'].apply(lambda f_l_mm: (f_l_mm - media_flipper_lenght) / desvio_padrao_flipper_lenght)
# Out:
# 200.96696696696696
# 14.015765288287882
# <ipython-input-12-a4fedc76d0e5>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['flipper_length_mm_std'] = penguins_clean_df['flipper_length_mm'].apply(lambda f_l_mm: (f_l_mm - media_flipper_lenght) / desvio_padrao_flipper_lenght)

# %%
# body_mass_g

media_body_mass = penguins_clean_df['body_mass_g'].mean()
print(media_body_mass)

desvio_padrao_body_mass = penguins_clean_df['body_mass_g'].std()
print(desvio_padrao_body_mass)

penguins_clean_df['body_mass_g_std'] = penguins_clean_df['body_mass_g'].apply(lambda b_m_g: (b_m_g - media_body_mass) / desvio_padrao_body_mass)
# Out:
# 4207.057057057057
# 805.2158019428966
# <ipython-input-13-f54c75979110>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['body_mass_g_std'] = penguins_clean_df['body_mass_g'].apply(lambda b_m_g: (b_m_g - media_body_mass) / desvio_padrao_body_mass)

# %%
penguins_clean_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  bill_length_mm_std  bill_depth_mm_std  \
# 0       3750.0    Male           -0.894695           0.779559
# 1       3800.0  Female           -0.821552           0.119404
# 2       3250.0  Female           -0.675264           0.424091
# 4       3450.0  Female           -1.333559           1.084246
# 5       3650.0    Male           -0.858123           1.744400
#
#    flipper_length_mm_std  body_mass_g_std
# 0              -1.424608        -0.567621
# 1              -1.067867        -0.505525
# 2              -0.425733        -1.188572
# 4              -0.568429        -0.940192
# 5              -0.782474        -0.691811

# %% [markdown]
# ### **1.3. Variáveis categóricas**

# %% [markdown]
# Identifique as variáveis categóricas nominais e ordinais, crie uma nova coluna aplicando a técnica correta de conversão a seus valores. A nova coluna deve ter o mesmo nome da coluna original acrescidade de "*_nom*" ou "*_ord*".

# %% [markdown]
# > **Nota**: Você não deve tratar a variável resposta.

# %%
# resposta da questão 1.3

penguins_clean_df[['species', 'island', 'sex']].head()
# Out:
#   species     island     sex
# 0  Adelie  Torgersen    Male
# 1  Adelie  Torgersen  Female
# 2  Adelie  Torgersen  Female
# 4  Adelie  Torgersen  Female
# 5  Adelie  Torgersen    Male

# %%
penguins_clean_df['species'].drop_duplicates()
# Out:
# 0         Adelie
# 152    Chinstrap
# 220       Gentoo
# Name: species, dtype: object

# %%
penguins_clean_df['island'].drop_duplicates()
# Out:
# 0     Torgersen
# 20       Biscoe
# 30        Dream
# Name: island, dtype: object

# %%
penguins_clean_df['sex'].drop_duplicates()
# Out:
# 0      Male
# 1    Female
# Name: sex, dtype: object

# %%
# species

penguins_clean_df['species_adelle_nom'] = penguins_clean_df['species'].apply(lambda species: 1 if species == 'Adelie' else 0)
penguins_clean_df['species_chinstrap_nom'] = penguins_clean_df['species'].apply(lambda species: 1 if species == 'Chinstrap' else 0)
penguins_clean_df['species_gentoo_nom'] = penguins_clean_df['species'].apply(lambda species: 1 if species == 'Gentoo' else 0)
# Out:
# <ipython-input-19-17fd0f971fd0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['species_adelle_nom'] = penguins_clean_df['species'].apply(lambda species: 1 if species == 'Adelie' else 0)
# <ipython-input-19-17fd0f971fd0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['species_chinstrap_nom'] = penguins_clean_df['species'].apply(lambda species: 1 if species == 'Chinstrap' else 0)
# <ipython-input-19-17fd0f971fd0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['species_gentoo_nom'] = penguins_clean_df['species'].apply(lambda species: 1 if species == 'Gentoo' else 0)

# %%
# island

penguins_clean_df['island_torgersen_nom'] = penguins_clean_df['island'].apply(lambda island: 1 if island == 'Torgersen' else 0)
penguins_clean_df['island_biscoe_nom'] = penguins_clean_df['island'].apply(lambda island: 1 if island == 'Biscoe' else 0)
penguins_clean_df['island_dream_nom'] = penguins_clean_df['island'].apply(lambda island: 1 if island == 'Dream' else 0)
# Out:
# <ipython-input-20-6280781726f3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['island_torgersen_nom'] = penguins_clean_df['island'].apply(lambda island: 1 if island == 'Torgersen' else 0)
# <ipython-input-20-6280781726f3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['island_biscoe_nom'] = penguins_clean_df['island'].apply(lambda island: 1 if island == 'Biscoe' else 0)
# <ipython-input-20-6280781726f3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['island_dream_nom'] = penguins_clean_df['island'].apply(lambda island: 1 if island == 'Dream' else 0)

# %%
# sex

penguins_clean_df['sex_male_nom'] = penguins_clean_df['sex'].apply(lambda sex: 1 if sex == 'Male' else 0)
penguins_clean_df['sex_female_nom'] = penguins_clean_df['sex'].apply(lambda sex: 1 if sex == 'Female' else 0)
# Out:
# <ipython-input-21-5baea947e119>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['sex_male_nom'] = penguins_clean_df['sex'].apply(lambda sex: 1 if sex == 'Male' else 0)
# <ipython-input-21-5baea947e119>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguins_clean_df['sex_female_nom'] = penguins_clean_df['sex'].apply(lambda sex: 1 if sex == 'Female' else 0)

# %%
penguins_clean_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  bill_length_mm_std  bill_depth_mm_std  \
# 0       3750.0    Male           -0.894695           0.779559
# 1       3800.0  Female           -0.821552           0.119404
# 2       3250.0  Female           -0.675264           0.424091
# 4       3450.0  Female           -1.333559           1.084246
# 5       3650.0    Male           -0.858123           1.744400
#
#    flipper_length_mm_std  body_mass_g_std  species_adelle_nom  \
# 0              -1.424608        -0.567621                   1
# 1              -1.067867        -0.505525                   1
# 2              -0.425733        -1.188572                   1
# 4              -0.568429        -0.940192                   1
# 5              -0.782474        -0.691811                   1
#
#    species_chinstrap_nom  species_gentoo_nom  island_torgersen_nom  \
# 0                      0                   0                     1
# 1                      0                   0                     1
# 2                      0                   0                     1
# 4                      0                   0                     1
# 5                      0                   0                     1
#
#    island_biscoe_nom  island_dream_nom  sex_male_nom  sex_female_nom
# 0                  0                 0             1               0
# 1                  0                 0             0               1
# 2                  0                 0             0               1
# 4                  0                 0             0               1
# 5                  0                 0             1               0

# %% [markdown]
# ### **1.4. Limpeza**

# %% [markdown]
# Descarte as colunas originais e mantenha apenas a variável resposta e as variáveis preditivas com o sufixo *_std*", *_nom*" e "*_ord*".

# %%
# resposta da questão 1.4

penguins = penguins_clean_df.drop(columns=['species', 'island', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex'])
penguins.head()
# Out:
#    bill_length_mm_std  bill_depth_mm_std  flipper_length_mm_std  \
# 0           -0.894695           0.779559              -1.424608
# 1           -0.821552           0.119404              -1.067867
# 2           -0.675264           0.424091              -0.425733
# 4           -1.333559           1.084246              -0.568429
# 5           -0.858123           1.744400              -0.782474
#
#    body_mass_g_std  species_adelle_nom  species_chinstrap_nom  \
# 0        -0.567621                   1                      0
# 1        -0.505525                   1                      0
# 2        -1.188572                   1                      0
# 4        -0.940192                   1                      0
# 5        -0.691811                   1                      0
#
#    species_gentoo_nom  island_torgersen_nom  island_biscoe_nom  \
# 0                   0                     1                  0
# 1                   0                     1                  0
# 2                   0                     1                  0
# 4                   0                     1                  0
# 5                   0                     1                  0
#
#    island_dream_nom  sex_male_nom  sex_female_nom
# 0                 0             1               0
# 1                 0             0               1
# 2                 0             0               1
# 4                 0             0               1
# 5                 0             1               0

# %% [markdown]
# ---
